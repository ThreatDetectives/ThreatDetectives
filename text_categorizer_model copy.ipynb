# %%
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### In the `read_csv` function, we have passed a parameter for *encoding*, because our data set contains non-english words that's not supported by the default pandas `read_csv` function.

# %%
dataset = pd.read_csv('./labeled_data.csv', encoding='ISO-8859-1')
dataset.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
dataset.describe().T
# Out:
#                       count          mean          std  min     25%      50%  \
# Unnamed: 0          24783.0  12681.192027  7299.553863  0.0  6372.5  12703.0
# count               24783.0      3.243473     0.883060  3.0     3.0      3.0
# hate_speech         24783.0      0.280515     0.631851  0.0     0.0      0.0
# offensive_language  24783.0      2.413711     1.399459  0.0     2.0      3.0
# neither             24783.0      0.549247     1.113299  0.0     0.0      0.0
# class               24783.0      1.110277     0.462089  0.0     1.0      1.0
#
#                         75%      max
# Unnamed: 0          18995.5  25296.0
# count                   3.0      9.0
# hate_speech             0.0      7.0
# offensive_language      3.0      9.0
# neither                 0.0      9.0
# class                   1.0      2.0

# %%
dt_transformed = dataset[['class', 'tweet']]
dt_transformed.head()
# Out:
#    class                                              tweet
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %% [markdown]
# # Cleaning the labeled data

# %%
#remove user names by pulling all the characters inbetween "@" and ":"
#removes hashtags and their text
#removes text starting with http
#removes the "RT"

import re

def remove_RT_user(text):
    tweet = re.sub("@[^\s]+", "", text)
    # hashtag = re.sub("#[^\s]+", "", tweet)
    hashtag = re.sub("#[\w|\d]+", "", tweet)
    remove_http = re.sub("(https?[a-zA-Z0-9]+)|(http?[a-zA-Z0-9]+)", "", hashtag)
    no_rt = re.sub("RT", "", remove_http)
    return no_rt

dt_transformed['tweet_wo_RT_username'] = dt_transformed['tweet'].apply(lambda x: remove_RT_user(x))
dt_transformed.head()
# Out:
#    class                                              tweet  \
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                                 tweet_wo_RT_username
# 0  !!!   As a woman you shouldn't complain about ...
# 1  !!!!!   boy dats cold...tyga dwn bad for cuffi...
# 2  !!!!!!!   Dawg!!!!   You ever fuck a bitch and...
# 3                !!!!!!!!!    she look like a tranny
# 4  !!!!!!!!!!!!!   The shit you hear about me mig...

# %%
# removing punctuation

import string
print(string.punctuation)

def remove_punctuation(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct)
    return words_wo_punct

dt_transformed['tweet_wo_RT_username_punct'] = dt_transformed['tweet_wo_RT_username'].apply(lambda x: remove_punctuation(x))
dt_transformed.head()
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#    class                                              tweet  \
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                                 tweet_wo_RT_username  \
# 0  !!!   As a woman you shouldn't complain about ...
# 1  !!!!!   boy dats cold...tyga dwn bad for cuffi...
# 2  !!!!!!!   Dawg!!!!   You ever fuck a bitch and...
# 3                !!!!!!!!!    she look like a tranny
# 4  !!!!!!!!!!!!!   The shit you hear about me mig...
#
#                           tweet_wo_RT_username_punct
# 0     As a woman you shouldnt complain about clea...
# 1     boy dats coldtyga dwn bad for cuffin dat ho...
# 2     Dawg   You ever fuck a bitch and she start ...
# 3                             she look like a tranny
# 4     The shit you hear about me might be true or...

# %%
# stopword = nltk.corpus.stopwords.words('english')
# print(stopword[:11])

# def remove_stopwords(text):
#     text = [word for word in text if word not in stopword]
#     return text

# dt_transformed['tweet_wo_RT_username_punct_stopwords'] = dt_transformed['tweet_wo_RT_username_punct'].apply(lambda x: remove_stopwords(x))
# dt_transformed.head()

# %%
# Tokenization = splitting strings into words

def tokenize(text):
    split = re.split("\W+", text)
    return split

dt_transformed['tweet_wo_RT_username_punct_split'] = dt_transformed['tweet_wo_RT_username_punct'].apply(lambda x: tokenize(x))
dt_transformed.head()
# Out:
#    class                                              tweet  \
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                                 tweet_wo_RT_username  \
# 0  !!!   As a woman you shouldn't complain about ...
# 1  !!!!!   boy dats cold...tyga dwn bad for cuffi...
# 2  !!!!!!!   Dawg!!!!   You ever fuck a bitch and...
# 3                !!!!!!!!!    she look like a tranny
# 4  !!!!!!!!!!!!!   The shit you hear about me mig...
#
#                           tweet_wo_RT_username_punct  \
# 0     As a woman you shouldnt complain about clea...
# 1     boy dats coldtyga dwn bad for cuffin dat ho...
# 2     Dawg   You ever fuck a bitch and she start ...
# 3                             she look like a tranny
# 4     The shit you hear about me might be true or...
#
#                     tweet_wo_RT_username_punct_split
# 0  [, As, a, woman, you, shouldnt, complain, abou...
# 1  [, boy, dats, coldtyga, dwn, bad, for, cuffin,...
# 2  [, Dawg, You, ever, fuck, a, bitch, and, she, ...
# 3                     [, she, look, like, a, tranny]
# 4  [, The, shit, you, hear, about, me, might, be,...

# %%
# Bag of Words
tweets = dt_transformed['tweet_wo_RT_username_punct_split']

# tweet_list = [item for sublist in tweets for item in sublist] 
tweet_list = tweets.explode()

vectorizer = CountVectorizer()
vectorizer.fit(tweet_list)
vectorizer.vocabulary_
# Out:
# {'as': 1349,
#  'woman': 23287,
#  'you': 23649,
#  'shouldnt': 16410,
#  'complain': 4122,
#  'about': 574,
#  'cleaning': 3855,
#  'up': 22288,
#  'your': 23668,
#  'house': 8950,
#  'amp': 1028,
#  'man': 11297,
#  'should': 16406,
#  'always': 976,
#  'take': 17961,
#  'the': 21200,
#  'trash': 21747,
#  'out': 13189,
#  'boy': 2657,
#  'dats': 4873,
#  'coldtyga': 4008,
#  'dwn': 5857,
#  'bad': 1666,
#  'for': 7033,
#  'cuffin': 4657,
#  'dat': 4865,
#  'hoe': 8715,
#  'in': 9263,
#  '1st': 158,
#  'place': 13866,
#  'dawg': 4885,
#  'ever': 6298,
#  'fuck': 7267,
#  'bitch': 2243,
#  'and': 1073,
#  'she': 16252,
#  'start': 17357,
#  'to': 21523,
#  'cry': 4624,
#  'be': 1915,
#  'confused': 4205,
#  'shit': 16319,
#  'look': 10971,
#  'like': 10738,
#  'tranny': 21717,
#  'hear': 8433,
#  'me': 11527,
#  'might': 11765,
#  'true': 21879,
#  'or': 13109,
#  'it': 9591,
#  'faker': 6517,
#  'than': 21177,
#  'who': 23084,
#  'told': 21551,
#  'ya': 23467,
#  'just': 9966,
#  'blows': 2452,
#  'meclaim': 11554,
#  'so': 16911,
#  'faithful': 6511,
#  'down': 5613,
#  'somebody': 16979,
#  'but': 3043,
#  'still': 17467,
#  'fucking': 7288,
#  'with': 23235,
#  'hoes': 8739,
#  'can': 3181,
#  'not': 12748,
#  'sit': 16576,
#  'hate': 8350,
#  'on': 13017,
#  'another': 1142,
#  'got': 7840,
#  'too': 21592,
#  'much': 12155,
#  'going': 7767,
#  'cause': 3355,
#  'im': 9206,
#  'tired': 21481,
#  'of': 12913,
#  'big': 2162,
#  'bitches': 2262,
#  'coming': 4072,
#  'us': 22342,
#  'skinny': 16627,
#  'girls': 7670,
#  'get': 7590,
#  'back': 1638,
#  'thats': 21198,
#  'that': 21191,
#  'hobbies': 8708,
#  'include': 9283,
#  'fighting': 6737,
#  'mariam': 11377,
#  'keeks': 10054,
#  'is': 9557,
#  'curves': 4706,
#  'everyone': 6316,
#  'lol': 10934,
#  'walked': 22717,
#  'into': 9481,
#  'conversation': 4290,
#  'this': 21295,
#  'smh': 16804,
#  'murda': 12198,
#  'gang': 7449,
#  'its': 9608,
#  'land': 10404,
#  'smoke': 16820,
#  'are': 1275,
#  'losers': 11011,
#  'yea': 23547,
#  'go': 7734,
#  'ig': 9150,
#  'only': 13041,
#  'thing': 21270,
#  'off': 12917,
#  'nigga': 12557,
#  'miss': 11862,
#  'plz': 13954,
#  'whatever': 23006,
#  'do': 5458,
#  'love': 11042,
#  'cut': 4721,
#  'everyday': 6311,
#  'black': 2356,
#  'bottle': 2617,
#  'broke': 2813,
#  'cant': 3214,
#  'tell': 21099,
#  'nothing': 12754,
#  'cancel': 3186,
#  'nino': 12633,
#  'see': 16020,
#  'these': 21243,
#  'wont': 23306,
#  'change': 3485,
#  'no': 12661,
#  'dont': 5556,
#  'even': 6291,
#  'suck': 17675,
#  'dick': 5232,
#  'kermit': 10093,
#  'videos': 22528,
#  'bout': 2636,
#  'tip': 21475,
#  'toeing': 21539,
#  'my': 12272,
#  'hardwood': 8316,
#  'floors': 6949,
#  'tcocou2wq5l4q': 18807,
#  'her': 8530,
#  'pussy': 14561,
#  'lips': 10804,
#  'heaven': 8453,
#  'doors': 5572,
#  'what': 22999,
#  'hitting': 8694,
#  'met': 11686,
#  'ocean': 12894,
#  'dr': 5636,
#  'gave': 7496,
#  'pill': 13797,
#  'need': 12418,
#  'trippy': 21854,
#  'hennessy': 8524,
#  'spend': 17152,
#  'money': 11978,
#  'how': 8963,
#  'want': 22743,
#  'business': 3026,
#  'txt': 22048,
#  'old': 12979,
#  'new': 12482,
#  'wetter': 22980,
#  'id': 9113,
#  'say': 15827,
#  'would': 23361,
#  'excited': 6356,
#  'if': 9147,
#  'aint': 842,
#  'murder': 12199,
#  'game': 7436,
#  'shut': 16452,
#  'youre': 23669,
#  'toes': 21540,
#  'done': 5543,
#  'stinks': 17475,
#  'bitter': 2335,
#  'wrap': 23373,
#  'angry': 1103,
#  'bird': 2207,
#  'theres': 21240,
#  'app': 1217,
#  'jus': 9964,
#  'meet': 11576,
#  'son': 17002,
#  'now': 12772,
#  'he': 8403,
#  'mane': 11313,
#  'ass': 1393,
#  'lames': 10392,
#  'crying': 4627,
#  'over': 13241,
#  'tears': 21064,
#  'clown': 3915,
#  'snoop': 16890,
#  'said': 15699,
#  '94': 523,
#  'we': 22854,
#  'momma': 11965,
#  'cats': 3349,
#  'inside': 9401,
#  'doghouse': 5492,
#  'most': 12071,
#  'hated': 8351,
#  'favorite': 6611,
#  'tcobmdsvmc3rc': 18710,
#  'nice': 12520,
#  'make': 11262,
#  'naughty': 12380,
#  'yello': 23583,
#  'real': 14883,
#  'body': 2489,
#  'south': 17073,
#  'chick': 3614,
#  'em': 6062,
#  'thick': 21257,
#  'tcobzrdl3kf7u': 18754,
#  'pimps': 13808,
#  'future': 7368,
#  'voice': 22617,
#  'post': 14124,
#  'picture': 13769,
#  '200': 163,
#  'likes': 10749,
#  'powerful': 14166,
#  'drug': 5745,
#  'tcor8jsymib5b': 20189,
#  'quick': 14660,
#  'piece': 13774,
#  'call': 3145,
#  'drive': 5713,
#  'by': 3086,
#  'running': 15631,
#  'round': 15557,
#  'here': 8538,
#  'some': 16976,
#  'brand': 2708,
#  'fucked': 7275,
#  'worst': 23356,
#  'theyll': 21252,
#  'send': 16080,
#  'them': 21214,
#  'guys': 8123,
#  'niggas': 12573,
#  'talk': 17978,
#  'trust': 21888,
#  'all': 904,
#  'yall': 23494,
#  'cuffing': 4658,
#  'never': 12478,
#  'have': 8368,
#  'dodge': 5468,
#  'bullet': 2949,
#  'da': 4751,
#  'pregnant': 14217,
#  'bound': 2631,
#  'thank': 21182,
#  'god': 7746,
#  'young': 23662,
#  'chamberlain': 3470,
#  'music': 12223,
#  'teanna': 21058,
#  'trump': 21885,
#  'probably': 14316,
#  'cleaner': 3852,
#  'twitter': 22034,
#  'gay': 7499,
#  'couldnt': 4398,
#  'wait': 22695,
#  'act': 650,
#  'tonight': 21576,
#  'ima': 9207,
#  'steal': 17400,
#  'his': 8670,
#  'cat': 3331,
#  'replace': 15143,
#  'pitbull': 13848,
#  'hes': 8569,
#  'gone': 7784,
#  'took': 21596,
#  'tic': 21401,
#  'tacs': 17946,
#  'movie': 12125,
#  'wanna': 22739,
#  'model': 11933,
#  'russell': 15645,
#  'simmons': 16517,
#  'wouldnt': 23363,
#  'mind': 11819,
#  'school': 15888,
#  'didnt': 5254,
#  'deal': 4926,
#  'teachers': 21046,
#  'retweet': 15260,
#  'fag': 6481,
#  'they': 21249,
#  'females': 6685,
#  'think': 21276,
#  'dating': 4872,
#  'cute': 4722,
#  'tcovxbjg26gsz': 20650,
#  'does': 5482,
#  'doing': 5499,
#  'stuff': 17616,
#  'him': 8643,
#  'simplyaddictedtoguys': 16526,
#  'tco1jl4hi8zmf': 18154,
#  'woof': 23313,
#  'hot': 8935,
#  'scally': 15843,
#  'lad': 10359,
#  'asked': 1381,
#  'other': 13168,
#  'kanye': 10001,
#  'yes': 23591,
#  'bring': 2789,
#  'ur': 22333,
#  'side': 16475,
#  'where': 23029,
#  'know': 10255,
#  'gf': 7607,
#  'friends': 7201,
#  'at': 1439,
#  'swear': 17844,
#  'tco3gzupfumev': 18263,
#  'soles': 16963,
#  'lemmie': 10601,
#  'eat': 5910,
#  'oreo': 13129,
#  'dishes': 5380,
#  'one': 13024,
#  'tcopxmga68nc1': 20089,
#  'maybe': 11483,
#  'youll': 23660,
#  'better': 2108,
#  'tcotprevwfq0s': 20418,
#  'red': 14961,
#  'malone': 11282,
#  'niggah': 12568,
#  'could': 4396,
#  'please': 13930,
#  'use': 22348,
#  'complete': 4128,
#  'sentences': 16094,
#  'why': 23113,
#  'eggplant': 5985,
#  'emoji': 6088,
#  'doey': 5486,
#  'looked': 10973,
#  'scream': 15940,
#  'lmao': 10858,
#  'hennessey': 8523,
#  'venom': 22470,
#  'gt': 8038,
#  'tcoi8egmnkaj9': 19320,
#  'sexy': 16173,
#  'seh': 16042,
#  'then': 21222,
#  'shower': 16425,
#  'curtainltlmao': 4701,
#  'every': 6304,
#  'pic': 13750,
#  'posted': 14127,
#  'because': 1954,
#  'racist': 14704,
#  'yo': 23619,
#  'skateboarding': 16604,
#  'wood': 23308,
#  'pushing': 14552,
#  'faggots': 6487,
#  'ball': 1727,
#  'life': 10705,
#  'tcovbczp6hmt7': 20574,
#  'baby': 1626,
#  'monkey': 11993,
#  'bathtime': 1875,
#  'tco7kpwadlf0r': 18472,
#  'awwwwe': 1581,
#  'soooo': 17024,
#  'adorable': 707,
#  'damn': 4796,
#  'skippy': 16635,
#  'kill': 10161,
#  'ant': 1150,
#  'sidewalk': 16487,
#  'was': 22773,
#  'way': 22835,
#  'pussyno': 14581,
#  'bs': 2889,
#  'must': 12232,
#  'gt30chance': 8039,
#  'tcoluubgl9y5u': 19700,
#  'rings': 15377,
#  'mvps': 12268,
#  'ppl': 14171,
#  'ghettohood': 7613,
#  'kid': 10141,
#  'growing': 8021,
#  'had': 8158,
#  'funnnnnnn': 7353,
#  'facts': 6472,
#  'tattoostattoo': 18063,
#  'tcozwnbhpdz8e': 21027,
#  'tattooing': 18061,
#  'nipples': 12641,
#  'wanting': 22747,
#  'cuteeeee': 4723,
#  'worshiping': 23354,
#  'tcor37cejcjou': 20182,
#  'wow': 23367,
#  'lost': 11017,
#  'those': 21318,
#  'buttcheek': 3054,
#  'piercings': 13781,
#  'tcoyn6guyouq6': 20914,
#  'yeah': 23552,
#  'shes': 16282,
#  'ok': 12966,
#  'sis': 16568,
#  'shed': 16256,
#  'rather': 14835,
#  'shrugs': 16445,
#  'shell': 16276,
#  'works': 23339,
#  'queer': 14647,
#  'gaywad': 7505,
#  'faggot': 6485,
#  'read': 14875,
#  'tweets': 22005,
#  'after': 761,
#  'wasnt': 22785,
#  'funny': 7354,
#  'ungrateful': 22204,
#  'tco06e77bgwbx': 18098,
#  'fr': 7122,
#  'lulwhore': 11118,
#  'been': 1973,
#  'kidnapped': 10147,
#  'alsarabsss': 962,
#  'beaner': 1924,
#  'mexican': 11702,
#  'happy': 8300,
#  'birthday': 2230,
#  'nigs': 12614,
#  'thanks': 21186,
#  'when': 23024,
#  'teacher': 21045,
#  'tells': 21102,
#  'homework': 8828,
#  'tcorkk5vawij1': 20224,
#  'eating': 5916,
#  'hell': 8498,
#  'john': 9858,
#  'paul': 13505,
#  'tcoosipbkpr9h': 19979,
#  'lil': 10758,
#  'ugly': 22100,
#  'bald': 1717,
#  'headed': 8412,
#  'stop': 17510,
#  'making': 11270,
#  'makeup': 11268,
#  'weave': 22876,
#  'leafs': 10521,
#  'win': 23179,
#  'riot': 15382,
#  'looting': 10999,
#  'nig': 12546,
#  'sucks': 17688,
#  'more': 12037,
#  'attend': 1476,
#  'tcoj906t5ze2r': 19409,
#  'year': 23563,
#  'come': 4056,
#  'food': 7015,
#  'car': 3242,
#  'retard': 15239,
#  'richnow': 15326,
#  'doesnt': 5483,
#  'show': 16423,
#  'hella': 8499,
#  'tinder': 21461,
#  'friend': 7196,
#  'anymore': 1180,
#  'chill': 3636,
#  'brought': 2842,
#  'prople': 14394,
#  'cowboys': 4446,
#  'shutup': 16457,
#  'lmaooooooooooo': 10870,
#  'tcoaanpsujmyi': 18611,
#  'ltbitch': 11084,
#  'depressing': 5117,
#  'shitfoh': 16325,
#  'girl': 7661,
#  'spitting': 17194,
#  'lbvsbitch': 10510,
#  'let': 10633,
#  'couple': 4421,
#  'cuzzo': 4740,
#  'page': 13327,
#  'jaillmao': 9662,
#  'trick': 21817,
#  'again': 768,
#  'harlem': 8319,
#  'shake': 16191,
#  'an': 1050,
#  'excuse': 6362,
#  'full': 7325,
#  '30': 263,
#  'seconds': 16010,
#  'amen': 999,
#  'miley': 11790,
#  'tcop2kb2tfyxrokay': 20006,
#  'bc': 1908,
#  'emotionally': 6096,
#  'damaged': 4788,
#  'foh': 6994,
#  'having': 8373,
#  'loyal': 11071,
#  'female': 6684,
#  'wayyyyy': 22845,
#  'idc': 9115,
#  'licking': 10695,
#  'meow': 11652,
#  'tcokeegdcjs5k': 19532,
#  'check': 3560,
#  'our': 13187,
#  '12th': 76,
#  'ny': 12846,
#  'fans': 6558,
#  'stands': 17331,
#  'happen': 8289,
#  'vixen': 22603,
#  'ent': 6161,
#  'ran': 14771,
#  'threw': 21346,
#  'foothill': 7031,
#  'okay': 12968,
#  'nudes': 12801,
#  'pat': 13476,
#  'blacklisted': 2361,
#  'holding': 8787,
#  'anyway': 1190,
#  'tcoxuccwoetmn': 20837,
#  'wrong': 23400,
#  'nobody': 12669,
#  'knows': 10262,
#  'upp': 22311,
#  'type': 22059,
#  'dm': 5447,
#  'readem': 14876,
#  'which': 23036,
#  'top': 21613,
#  'baseball': 1842,
#  'season': 15993,
#  'started': 17358,
#  'little': 10832,
#  'stupid': 17629,
#  'yoooooouuuu': 23641,
#  'really': 14898,
#  'dead': 4919,
#  'serious': 16114,
#  'tho': 21305,
#  'wheet': 23022,
#  'early': 5890,
#  'night': 12605,
#  'owl': 13284,
#  'wise': 23220,
#  'worms': 23345,
#  'overdosing': 13246,
#  'heavy': 8457,
#  'drugs': 5747,
#  'sound': 17063,
#  'day': 4891,
#  'pit': 13847,
#  'bulls': 2955,
#  'photographed': 13736,
#  'lovely': 11049,
#  'fairy': 6508,
#  'tale': 17971,
#  'creatures': 4529,
#  'tcoq0sm89oolh': 20097,
#  'aw': 1548,
#  'tweet': 21995,
#  'long': 10962,
#  'lakers': 10381,
#  'from': 7221,
#  'careless': 3261,
#  'cc': 3368,
#  'hahaha': 8169,
#  'anything': 1184,
#  'kiss': 10207,
#  'play': 13900,
#  'soccer': 16925,
#  'cheat': 3553,
#  'wear': 22869,
#  'khaki': 10116,
#  'coloured': 4039,
#  'cargos': 3267,
#  'haircut': 8195,
#  'tcozuai7qwbir': 21018,
#  'yup': 23711,
#  'fat': 6590,
#  'lap': 10416,
#  'same': 15735,
#  '17': 107,
#  'missed': 11863,
#  'calls': 3155,
#  'das': 4861,
#  'po': 13959,
#  'finna': 6802,
#  'screamn': 15944,
#  'gotta': 7850,
#  'rules': 15617,
#  'shitanybody': 16321,
#  'ask': 1378,
#  'cousin': 4431,
#  'jersey': 9772,
#  'thinkin': 21279,
#  'moving': 12128,
#  'lmmfao': 10894,
#  'amo': 1021,
#  'los': 11008,
#  'pies': 13783,
#  'tco4qe1hdkk8i': 18335,
#  'thinking': 21280,
#  'meat': 11550,
#  'slap': 16672,
#  'ainna': 840,
#  'bruh': 2859,
#  'wit': 23228,
#  'edges': 5947,
#  'talking': 17987,
#  'treating': 21789,
#  'nahhell': 12310,
#  'sweet': 17858,
#  'tooth': 21606,
#  'bandit': 1762,
#  'bags': 1691,
#  'sex': 16158,
#  'mom': 11961,
#  'right': 15355,
#  'came': 3166,
#  'hacked': 8152,
#  'eyes': 6441,
#  'open': 13076,
#  'watch': 22801,
#  'bitchlmfao': 2301,
#  'woulda': 23362,
#  'coulda': 4397,
#  'shoulda': 16407,
#  'bday': 1913,
#  'roll': 15489,
#  'used': 22349,
#  'own': 13285,
#  'wcw': 22851,
#  'duh': 5797,
#  'elses': 6057,
#  'hacky': 8157,
#  'sack': 15672,
#  'nah': 12308,
#  'throw': 21360,
#  'passes': 13465,
#  'glad': 7687,
#  'getting': 7599,
#  'outta': 13226,
#  'atlanta': 1454,
#  'bunch': 2981,
#  'jail': 9660,
#  'dumb': 5805,
#  'mad': 11205,
#  'kids': 10149,
#  'fuckin': 7287,
#  'isnt': 9576,
#  'ghettoits': 7614,
#  'smart': 16782,
#  'tcompazq3jswf': 19777,
#  'wife': 23133,
#  'cuz': 4737,
#  'care': 3255,
#  'cheating': 3557,
#  'each': 5875,
#  'force': 7035,
#  'relationship': 15072,
#  'first': 6820,
#  'being': 2010,
#  'single': 16549,
#  'white': 23067,
#  'power': 14162,
#  'lets': 10638,
#  'drunk': 5755,
#  'blowed': 2448,
#  'spit': 17188,
#  'spark': 17103,
#  'blunts': 2461,
#  'bro': 2803,
#  'dudes': 5790,
#  'around': 1313,
#  'world': 23341,
#  'sucked': 17678,
#  'party': 13456,
#  'set': 16133,
#  'has': 8338,
#  'lot': 11020,
#  'cartoon': 3306,
#  'theirs': 21212,
#  'alway': 975,
#  'saving': 15817,
#  'tco9ukd8wtz6x': 18581,
#  'captain': 3234,
#  'saveahoe': 15812,
#  'wants': 22749,
#  'there': 21234,
#  'nose': 12745,
#  'bois': 2499,
#  'tcofeqxgn0w6i': 19058,
#  'sox': 17083,
#  'legs': 10593,
#  'wish': 23221,
#  'brother': 2839,
#  'keezy': 10063,
#  'ooooow': 13067,
#  'bet': 2096,
#  'dressed': 5684,
#  'halloween': 8226,
#  'basic': 1850,
#  'pornhub': 14086,
#  'gaming': 7445,
#  'stream': 17550,
#  'feature': 6639,
#  'gtfo': 8043,
#  'katielt3': 10027,
#  'scared': 15855,
#  'choke': 3687,
#  'during': 5836,
#  'says': 15833,
#  'guy': 8122,
#  'hits': 8689,
#  'women': 23290,
#  'bed': 1960,
#  'ha': 8144,
#  'well': 22938,
#  'iguess': 9165,
#  'oh': 12947,
#  'am': 980,
#  'molly': 11958,
#  'ho': 8707,
#  'seed': 16021,
#  'refer': 14999,
#  'lmfao': 10878,
#  'beating': 1944,
#  'finally': 6770,
#  'peel': 13568,
#  'rewind': 15290,
#  'move': 12120,
#  'shaq': 16215,
#  'line': 10781,
#  'tf': 21167,
#  'io': 9514,
#  'alu': 972,
#  'record': 14951,
#  'vine': 22550,
#  'sai': 15698,
#  'pe': 13533,
#  'hahahaha': 8174,
#  'anywaaaaaays': 1189,
#  'haha': 8166,
#  'naw': 12383,
#  'tape': 18021,
#  'cover': 4434,
#  'upcoming': 22293,
#  'mixtape': 11889,
#  'waiting': 22699,
#  'mayne': 11485,
#  'ol': 12978,
#  'dirty': 5337,
#  'foot': 7027,
#  'yellow': 23584,
#  'flags': 6863,
#  'amazing': 991,
#  'niggy': 12601,
#  'time': 21447,
#  'actin': 652,
#  'iffy': 9148,
#  'stay': 17387,
#  'alive': 903,
#  'knights': 10240,
#  'nation': 12364,
#  'special': 17126,
#  'tcoh1ubsvbkgl': 19217,
#  'smfh': 16802,
#  'wonder': 23297,
#  'decent': 4957,
#  'studs': 17612,
#  'keep': 10056,
#  'soft': 16946,
#  'many': 11349,
#  'times': 21452,
#  'screamed': 15941,
#  'stfu': 17453,
#  'bye': 3087,
#  'dry': 5762,
#  'blame': 2372,
#  'condom': 4179,
#  'tcoiemn1u0gm5': 19335,
#  'gucci': 8072,
#  'dropping': 5734,
#  'mixtapes': 11890,
#  'month': 12008,
#  'text': 21158,
#  'wats': 22820,
#  'burbs': 2995,
#  'without': 23242,
#  'daddy': 4762,
#  'issues': 9587,
#  'finding': 6777,
#  'holographic': 8807,
#  'mewtwo': 11700,
#  'sounding': 17066,
#  'easy': 5909,
#  'cum': 4666,
#  'fact': 6467,
#  'charlie': 3523,
#  'sheen': 16261,
#  'tcogggdk3kov7': 19144,
#  'major': 11259,
#  'respect': 15205,
#  'bae': 1682,
#  'twerking': 22012,
#  'cook': 4309,
#  'wtf': 23408,
#  'tcodasmycxodb': 18861,
#  'zoe': 23770,
#  'fight': 6733,
#  'good': 7792,
#  'maam': 11182,
#  'along': 951,
#  'snake': 16846,
#  'booty': 2576,
#  'everywhere': 6321,
#  'sheesh': 16266,
#  'tuned': 21941,
#  'update': 22295,
#  'report': 15152,
#  '1b': 148,
#  'will': 23163,
#  '810': 489,
#  'weeks': 22905,
#  'tcotycihd6pkw': 20454,
#  'oregon': 13127,
#  'chokes': 3690,
#  'field': 6728,
#  'program': 14349,
#  'rft': 15297,
#  'def': 4997,
#  'cowboy': 4445,
#  'terrell': 21136,
#  'owens': 13281,
#  'best': 2088,
#  'eagle': 5880,
#  'dude': 5789,
#  'cried': 4547,
#  'tv': 21977,
#  'romo': 15505,
#  'lmfaoooo': 10881,
#  'people': 13604,
#  'tcornvd2nlcdr': 20237,
#  'niggers': 12586,
#  'potent': 14139,
#  'tco3jk4kr44x3': 18266,
#  'pissed': 13837,
#  'past': 13470,
#  'lick': 10691,
#  'while': 23042,
#  'slept': 16704,
#  'tcoprrskknqrv': 20067,
#  'frat': 7139,
#  'tcoxpsc3makgj': 20825,
#  'arches': 1272,
#  'fam': 6536,
#  'depends': 5111,
#  'feel': 6655,
#  'hicks': 8599,
#  'confusing': 4206,
#  'america': 1003,
#  'toto': 21645,
#  'means': 11541,
#  'vaginai': 22405,
#  'santi': 15769,
#  'nasty': 12358,
#  'actually': 669,
#  'choose': 3698,
#  'vibe': 22511,
#  'tried': 21825,
#  'dis': 5340,
#  'saying': 15830,
#  'mean': 11534,
#  'af': 737,
#  'tight': 21427,
#  'shirts': 16317,
#  'grim': 7981,
#  'everybody': 6306,
#  '10': 12,
#  'birds': 2219,
#  'grandkids': 7907,
#  'may': 11481,
#  'climate': 3876,
#  'tcoxqmxhkaswt': 20828,
#  'tcorbitegrnhm': 20197,
#  'beautiful': 1948,
#  'purple': 14539,
#  'ceeeleeeman': 3385,
#  'gurl': 8109,
#  'playin': 13917,
#  'track': 21683,
#  'shitted': 16339,
#  'sum': 17715,
#  'gurls': 8112,
#  'taller': 17993,
#  'blurry': 2463,
#  'seen': 16036,
#  'obsessed': 12879,
#  'mine': 11823,
#  'kobe': 10279,
#  'forget': 7058,
#  'tcovh4tnekvtp': 20603,
#  'meant': 11544,
#  'least': 10536,
#  'nigger': 12581,
#  'tcorgja7cfoit': 20214,
#  'asking': 1384,
#  'mixed': 11887,
#  'asian': 1372,
#  'ariza': 1300,
#  'coward': 4442,
#  'cripple': 4557,
#  'hero': 8554,
#  'roach': 15421,
#  'lmaoo': 10863,
#  'fosters': 7098,
#  'home': 8811,
#  'imaginary': 9211,
#  'whoa': 23085,
#  'everything': 6318,
#  'lowkey': 11065,
#  'quiet': 14666,
#  'sleep': 16694,
#  'bringing': 2791,
#  'weird': 22924,
#  'mentions': 11648,
#  'tcocussdjesrk': 18820,
#  'homeboys': 8813,
#  'weak': 22858,
#  'advice': 726,
#  'speed': 17144,
#  'quote': 14678,
#  'animalpussy': 1106,
#  'strippers': 17579,
#  'theyre': 21253,
#  'dancers': 4810,
#  'ballet': 1733,
#  'pop': 14059,
#  'their': 21211,
#  'beethoven': 1982,
#  'stripper': 17578,
#  'andrewbryant': 1084,
#  'poff': 13975,
#  'double': 5595,
#  'vision': 22584,
#  'beers': 1980,
#  'twerk': 22010,
#  'computer': 4144,
#  'prince': 14287,
#  'art': 1335,
#  'tcoephrwxmbhr': 18996,
#  'takin': 17967,
#  '61': 428,
#  'welfaregovernment': 22937,
#  'aid': 831,
#  'claimed': 3814,
#  'slander': 16667,
#  'role': 15486,
#  'find': 6774,
#  'hiding': 8608,
#  'lime': 10767,
#  ...}

# %%
tweets = dt_transformed[['tweet']]
type(tweets)
# Out:
# pandas.core.frame.DataFrame

# %%
[tweet for tweet in dt_transformed['tweet_wo_RT_username_punct_split']]
# Out:
# ,
#   'it'],
#  ['',
#   'I',
#   'went',
#   'to',
#   'Golds',
#   'with',
#   'Cruz',
#   'in',
#   '2010',
#   'when',
#   'he',
#   'was',
#   'a',
#   'Sound',
#   'No',
#   'upper',
#   'lower',
#   'body',
#   'strength',
#   'Hmm',
#   'now',
#   '40',
#   'HR',
#   'hitter',
#   'Wont',
#   'say',
#   'the',
#   'S',
#   'word'],
#  ['',
#   'If',
#   'Royals',
#   'have',
#   'a',
#   'fire',
#   'sale',
#   'I',
#   'want',
#   'the',
#   'whole',
#   'team',
#   'Leave',
#   'Gardner',
#   'and',
#   'Tanaka',
#   'The',
#   'rest',
#   'can',
#   'please',
#   'go',
#   'Along',
#   'with',
#   'Joe',
#   'and',
#   'Cash'],
#  ['', 'Nice', 'bounce', 'back', 'Kay', 'Gotta', 'keep', 'this', 'going'],
#  ['', 'Pineda', 'needed', 'that', '67', 'Great', 'play'],
#  ['',
#   'Primo',
#   'Just',
#   'got',
#   'home',
#   'and',
#   'the',
#   'Tanks',
#   'are',
#   'on',
#   'MLB',
#   'Finally',
#   'And',
#   'they',
#   'are',
#   'winning',
#   'Even',
#   'better',
#   'Time',
#   'to',
#   'get',
#   'serious',
#   'Sept',
#   'call',
#   'up',
#   'time'],
#  ['', 'got', 'beaten', 'by', 'a', 'thug'],
#  ['',
#   'take',
#   'all',
#   'three',
#   'games',
#   'in',
#   'MoTown',
#   'Im',
#   'callin',
#   'it',
#   ''],
#  ['', 'wasted', 'Nuezs', 'season', ''],
#  ['',
#   'start',
#   'building',
#   'SO',
#   'FUCKIN',
#   'BIG',
#   'they',
#   'can',
#   'kill',
#   'a',
#   'whole',
#   'flock',
#   'of',
#   'birds',
#   'in',
#   'one',
#   'gogt'],
#  ['',
#   'tattoo',
#   'our',
#   'bitches',
#   'to',
#   'corrupt',
#   'as',
#   'many',
#   'men',
#   'as',
#   'possible',
#   'to',
#   'and',
#   'being',
#   'a',
#   'gt'],
#  ['', 'youre', 'proud', 'to', 'be', 'white', 'trash', ''],
#  ['',
#   'There',
#   'are',
#   'a',
#   'few',
#   'badd',
#   'ones',
#   'but',
#   'idkmixxed',
#   'bitches',
#   'is',
#   'really',
#   'where',
#   'its',
#   'at',
#   'tho'],
#  ['',
#   'LA',
#   'palm',
#   'trees',
#   'and',
#   'great',
#   'weather',
#   'Any',
#   'were',
#   'else',
#   'horrible',
#   'weather',
#   'and',
#   'no',
#   'bitches'],
#  ['', ''],
#  ['', 'bitches'],
#  ['',
#   'in',
#   'this',
#   'bitch',
#   '40st',
#   'and',
#   'Washington',
#   'space',
#   'A80',
#   'tcoH2HV64h9wh'],
#  ['', 'leaving', 'hoes', 'w', ''],
#  ['', 'The', 'Draught', 'Horse', 'tcoUvWkhpEswh'],
#  ['',
#   'KILLED',
#   'gt',
#   'HELLO',
#   'But',
#   'whatever',
#   'Go',
#   'ahead',
#   'yourself',
#   'into',
#   's',
#   'pocketsgt'],
#  ['',
#   'are',
#   'MERELY',
#   'a',
#   'indicator',
#   'that',
#   'SOMETHING',
#   'IS',
#   'WRONGgt',
#   'Do',
#   'not',
#   'celebrate',
#   'as',
#   'unique',
#   'indiviuals',
#   'for',
#   'they',
#   'are',
#   'gt'],
#  ['', 'is', 'a', 'job', 'for', 'white', 'trash'],
#  ['',
#   'cuts',
#   'away',
#   'when',
#   'a',
#   'Democrat',
#   'talks',
#   'and',
#   'claim',
#   'to',
#   'be',
#   'fair',
#   'and',
#   'balanced',
#   'LMAO',
#   'network',
#   'full',
#   'of',
#   'and',
#   'liars'],
#  ['', 'wishing', 'tcol73hiK0IZ8'],
#  ['', 'we', 'dont', 'love', 'these', 'hoes'],
#  ['', 'bitch'],
#  ['',
#   'fans',
#   'is',
#   'cody',
#   'zeller',
#   'nominating',
#   'for',
#   'this',
#   'years',
#   'draft',
#   ''],
#  ['',
#   'anyone',
#   'from',
#   'Jersey',
#   'Shore',
#   'is',
#   'famous',
#   'I',
#   'should',
#   'go',
#   'be',
#   'a',
#   'guido',
#   'shitbag',
#   'if',
#   'it',
#   'means',
#   'money',
#   'for',
#   'my',
#   'family'],
#  ['',
#   'snappy',
#   'pappy',
#   'and',
#   'his',
#   'bitch',
#   '35x25',
#   'good',
#   'thing',
#   'sable',
#   'paintbrushes',
#   'tco4gYBEI5Mkl'],
#  ['',
#   'Still',
#   'hanging',
#   'in',
#   'we',
#   'need',
#   'this',
#   'win',
#   'NFL',
#   'Its',
#   'not',
#   'SUNDAY'],
#  ['', 'suiting', 'up', 'again', 'tonight', ''],
#  ['', 'this', 'bitch', 'has', 'his', 'nose', 'pierced', 'tco1Ia8Nx6zrS'],
#  ['',
#   'dont',
#   'care',
#   'got',
#   'my',
#   'everywhere',
#   'Im',
#   'a',
#   'Im',
#   'a',
#   'Im',
#   'totally',
#   'full',
#   'of',
#   'tcoQia88qGmWh'],
#  ['', 'only', 'honkies'],
#  ['', 'tcog3Ze8bqLPG'],
#  ['',
#   'prove',
#   'him',
#   'wrong',
#   'righties',
#   'Liberals',
#   'use',
#   'facts',
#   'cons',
#   'use',
#   'emotions',
#   'to',
#   'make',
#   'decisions',
#   'Facts',
#   'be',
#   'damned',
#   'should',
#   'be',
#   'the',
#   'teabagger',
#   'motto'],
#  ['', 'tcovii3SmGRm3'],
#  ['', 'tcohueH4HCxx7'],
#  ['', 'browngal', 'tcokFhj8lWhbs'],
#  ['', 'bitch', 'GET', 'AT', 'ME', 'tco5FJForyY2e'],
#  ['',
#   'witcha',
#   'bitch',
#   'pussy',
#   'pussy',
#   'inda',
#   'hood',
#   'ona',
#   'sofawit',
#   'plastic',
#   'on',
#   'it'],
#  ['',
#   'Shy',
#   'Glizzy',
#   'Awwsome',
#   'Remix',
#   'Feat',
#   '2',
#   'Chainz',
#   'amp',
#   'AAP',
#   'Rocky',
#   'via',
#   'tcoOWxtdRKWbC'],
#  ['',
#   'can',
#   'get',
#   'it',
#   'but',
#   'Im',
#   'chilling',
#   'till',
#   'da',
#   'bitch',
#   'hit',
#   'me',
#   'up'],
#  ['',
#   'but',
#   'niggas',
#   'is',
#   'bitches',
#   'tho',
#   'Boy',
#   'niggaz',
#   'b',
#   'so',
#   'bitch',
#   'made',
#   'u',
#   'cud',
#   'kiss',
#   'em',
#   'n',
#   'da',
#   'mouth'],
#  ['', 'better', 'then', 'UR', 'whole', 'team'],
#  ['',
#   'Anal',
#   'gaping',
#   'tranny',
#   'play',
#   'panty',
#   'nylon',
#   'part',
#   'tco35oTesnwmx'],
#  ['', 'BBC', 'Anal', 'creampie', 'bitch', 'tco3XNeG5mnRk'],
#  ['', 'Blonde', 'tranny', 'ass', 'fucked', 'tco80aRX0QJxz'],
#  ['', 'Hardcore', 'british', 'queer', 'anal', 'pounding', 'tcolRuEixMy21'],
#  ['',
#   'Brazilian',
#   'BBW',
#   'Babe',
#   'Drilled',
#   'in',
#   'pussy',
#   'and',
#   'ass',
#   'tcoZ7ksrFpmz9'],
#  ['', 'ebony', 'babe', 'pussy', 'tco3MxBXeZqxR'],
#  ['',
#   'Caught',
#   'a',
#   'girl',
#   'rubbing',
#   'her',
#   'pussy',
#   'in',
#   'nude',
#   'beach',
#   'tcoh8lGiTFYie'],
#  ['',
#   'Cute',
#   'preggie',
#   'slut',
#   'big',
#   'tits',
#   'plays',
#   'with',
#   'swollen',
#   'pussy',
#   'tcoiTCpEBCem4'],
#  ['', 'Up', 'Another', 'pussy', 'close', 'up', 'tcohBjDGvENXa'],
#  ['', 'Squirting', 'pussy', 'and', 'fingered', 'asshole', 'tcobKYeoUwWv2'],
#  ['', 'amateur', 'pussy', 'player', 'milf', 'close', 'up', 'tco2uHL7dhHu1'],
#  ['', 'cumshot', 'on', 'beauty', 'pussy', 'closeup', 'tcoUonsdrAuV0'],
#  ['', 'pussy', 'fuck', 'close', 'up', 'tco0dvaZWLq2q'],
#  ['', 'Young', 'Japanese', 'girls', 'hairy', 'cunt', 'cre', 'tcol46q7MoGGr'],
#  ['',
#   'Spicy',
#   'Oriental',
#   'Paki',
#   'Brunette',
#   'sucks',
#   'an',
#   'un',
#   'tcoOrP642PomF'],
#  ['', 'paki', 'tcoXxcdQvzI9t'],
#  ['', 'paki', 'tcocOfGRtW9br'],
#  ['',
#   'ebony',
#   'texas',
#   'bbw',
#   'with',
#   'big',
#   'deep',
#   'pussy',
#   'tcodBbxsoW8M2'],
#  ['',
#   'Erotic',
#   'and',
#   'wild',
#   'tits',
#   'and',
#   'pussy',
#   'fucking',
#   'tco8HkC56j7c9'],
#  ['',
#   'Blonde',
#   'tranny',
#   'whore',
#   'gets',
#   'rammed',
#   'and',
#   'facialized',
#   'tcoKd9nU3tmWz'],
#  ['', 'Dude', 'fists', 'his', 'wifes', 'big', 'pussy', 'tcosnFAf5Uxxb'],
#  ['',
#   'More',
#   'lovely',
#   'sounds',
#   'of',
#   'fisting',
#   'a',
#   'loose',
#   'pussy',
#   'tco1PMAGSPkud'],
#  ['', 'Whipped', 'Cream', 'Fisting', 'tcob4JCMCtEwq'],
#  ['',
#   '21',
#   'year',
#   'old',
#   'hairy',
#   'pussy',
#   'cumming',
#   'on',
#   'fingers',
#   'tcoKvgoxkN9vG'],
#  ['',
#   'Hairy',
#   'Florence',
#   'shoves',
#   'a',
#   'dildo',
#   'in',
#   'her',
#   'hairy',
#   'red',
#   'pussy',
#   'tco4DM8Fpcb2d'],
#  ['', 'Hairy', 'pussy', 'tco9DOIbSkT17'],
#  ['', 'hairy', 'pussy', 'tcoNtg2b0qDmx'],
#  ['', 'Hand', 'job', 'and', 'cum', 'on', 'rubber', 'pussy', 'tcozGcnmR2kLA'],
#  ['', 'Amateur', 'boy', 'fucking', 'bitch', 'hiddencam', 'tcoBt8C6qQCTd'],
#  ['', 'Candid', 'pussy', 'shots', 'from', 'a', 'hidden', 'c', 'tcoIKpJ0etz71'],
#  ['',
#   'Home',
#   'made',
#   'My',
#   'wife',
#   'rubbing',
#   'her',
#   'pussy',
#   'tcoldb9aFwVdM'],
#  ['',
#   'Using',
#   'my',
#   'submissive',
#   'bitch',
#   'outdoor',
#   'Home',
#   'made',
#   'amateur',
#   'tcoFu6AggzHQd'],
#  ['', 'my', 'baby', 'pussy', 'tco1O7AJdBjLc'],
#  ['',
#   'Pretty',
#   'young',
#   'Japanese',
#   'girls',
#   'hot',
#   'cunt',
#   'fucked',
#   'amp',
#   'c',
#   'tcowt5SSOF9rW'],
#  ['',
#   'Young',
#   'Japanese',
#   'girls',
#   'hairy',
#   'cunt',
#   'creampied',
#   'tcorg3PObaKKD'],
#  ['', 'korean', 'girlfriend', 'pussy', 'tcoOd1MQUudnN'],
#  ['', 'Latina', 'chick', 'gets', 'her', 'pussy', 'pumped', 'tco4dhwuI5ARd'],
#  ['', 'Latina', 'mature', 'Big', 'pussy', 'tcoD4ICvCz1Bk'],
#  ['', 'Latina', 'with', 'tight', 'pussy', 'tcorDaOnqVr1H'],
#  ['', 'Lesbian', 'girl', 'eating', 'pussy', 'tcoHt9szL3b24'],
#  ['',
#   'Bitch',
#   'in',
#   'lingerie',
#   'getting',
#   'her',
#   'wet',
#   'cunt',
#   'pounded',
#   'tcoJp4r2vPyCb'],
#  ['', 'A', 'very', 'hot', 'black', 'tranny', 'is', 'mastu', 'tcoOfGGMLXQAj'],
#  ['',
#   'Old',
#   'bitch',
#   'pleases',
#   'hotlooking',
#   'young',
#   'stud',
#   'tcoaIDKdmztLn'],
#  ['',
#   'german',
#   'milf',
#   'getting',
#   'young',
#   'and',
#   'old',
#   'cock',
#   'in',
#   'her',
#   'pussy',
#   'tcokXhzjwG4Ii'],
#  ['',
#   'Small',
#   'tits',
#   'ghetto',
#   'whore',
#   'fucking',
#   'with',
#   'not',
#   'her',
#   'stepdad',
#   'tcoAy6gRNTOUw'],
#  ['', 'Cutie', 'lesbian', 'teens', 'toy', 'slits', 'tcoZS05enjjwm'],
#  ['',
#   'Hairy',
#   'Alicia',
#   'Silver',
#   'amp',
#   'Tinslee',
#   'Reagan',
#   'hairy',
#   'pussy',
#   'tcoToljqdXEE3'],
#  ['', 'homemade', 'pussy', 'eating', 'tco2yuIdrLN3k', 'tcoZ8GAiWlLye'],
#  ['',
#   'The',
#   'Xbox',
#   'One',
#   'would',
#   'be',
#   'so',
#   'much',
#   'cooler',
#   'if',
#   'they',
#   'put',
#   'a',
#   'bird',
#   'on',
#   'it'],
#  ['',
#   'Dont',
#   'tell',
#   'me',
#   'if',
#   'my',
#   'gf',
#   'was',
#   'a',
#   'hoe',
#   'before',
#   'me',
#   'if',
#   'Im',
#   'happy'],
#  ['',
#   'if',
#   'you',
#   'a',
#   'hoe',
#   'an',
#   'try',
#   'to',
#   'get',
#   'serious',
#   'with',
#   'someone',
#   'dont',
#   'expect',
#   'to',
#   'be',
#   'anything',
#   'more',
#   'then',
#   'a',
#   'piece',
#   'of',
#   'meat',
#   'to',
#   'them'],
#  ['', 'tow', 'truck', 'tcoiFInqwVRad'],
#  ['', 'Its', 'The', 'Grape', 'Crackhead', 'Charlie', 'Brown'],
#  ['',
#   'has',
#   'a',
#   'highschool',
#   'graduation',
#   'rate',
#   'near',
#   '50',
#   'and',
#   'thats',
#   'why',
#   'they',
#   'have',
#   'so',
#   'many',
#   'uninformed',
#   ''],
#  ['',
#   'would',
#   'last',
#   '15mins',
#   'if',
#   'they',
#   'let',
#   'the',
#   'President',
#   'talk',
#   'all',
#   'that',
#   'standing',
#   'up',
#   'clapping',
#   'is',
#   'for',
#   'the',
#   'birds'],
#  ['', 'me', 'being', 'a', 'bad', 'bitch', 'tcoJc4bKbe8Vt'],
#  ['', 'my', 'precious', 'gook', 'baby', 'tco2QJLJj6tK5'],
#  ['',
#   'to',
#   'when',
#   'i',
#   'used',
#   'to',
#   'be',
#   'good',
#   'at',
#   'rappingnow',
#   'ima',
#   'bitch',
#   'tco6RV4jiJpRD'],
#  ['',
#   'when',
#   'i',
#   'took',
#   'my',
#   'likkle',
#   'monkey',
#   'jimmys',
#   'tcoLIK3xpZ6eZ'],
#  ['',
#   'state',
#   'like',
#   'mississippi',
#   'opposed',
#   'to',
#   'minimum',
#   'wage',
#   'child',
#   'labor',
#   'laws',
#   'unions',
#   'is',
#   'proscab',
#   'sweatshop',
#   'work',
#   'pretty',
#   'much',
#   ''],
#  ['',
#   'to',
#   'being',
#   'bitches',
#   'amp',
#   'drinking',
#   'Mikes',
#   'bc',
#   'we',
#   'sucked',
#   'tcojfCthdEDcz'],
#  ['',
#   'rough',
#   'mock',
#   'for',
#   'the',
#   'base',
#   'of',
#   'what',
#   'will',
#   'eventually',
#   'be',
#   'an',
#   'ashtray',
#   'Tiki',
#   'Ti',
#   'tco8zE8aqY0'],
#  ['', 'my', 'bitch', 'tco7dSZ3vCySz'],
#  ['',
#   'Nah',
#   'we',
#   'not',
#   'gonna',
#   'sit',
#   'down',
#   'we',
#   'gonna',
#   'walk',
#   'it',
#   'out',
#   'bitch'],
#  ['',
#   'bitch',
#   'get',
#   'naked',
#   'Works',
#   '10',
#   'times',
#   'out',
#   'of',
#   '10',
#   'if',
#   'shes',
#   'drunk',
#   ''],
#  ['',
#   'loving',
#   'the',
#   'show',
#   'this',
#   'morning',
#   'Chris',
#   'is',
#   'directing',
#   'the',
#   'conversation',
#   'beautifully',
#   'Make',
#   'the',
#   'teabaggers',
#   'talk'],
#  ['', 'tcowbAqQ5vFpd'],
#  ['', 'bitch'],
#  ['', 'all', 'the', 'bad', 'bitches', ''],
#  ['', 'bitch', 'tco7n5X9FyvIP'],
#  ['',
#   'everytime',
#   'I',
#   'come',
#   'in',
#   'the',
#   'kitchen',
#   'you',
#   'in',
#   'the',
#   'kitchen',
#   'in',
#   'the',
#   'goddamn',
#   'refrigerator',
#   'Eatin',
#   'up',
#   'all',
#   'the',
#   'pussy'],
#  ['',
#   'sick',
#   'of',
#   'guys',
#   'who',
#   'sing',
#   'like',
#   'pussies',
#   'Where',
#   'are',
#   'the',
#   'rock',
#   'type',
#   'men'],
#  ['', 'if', 'u', 'a', 'real', 'bitch'],
#  ['100',
#   'bid',
#   'to',
#   'go',
#   'on',
#   'a',
#   'date',
#   'with',
#   'Zack',
#   'Morris',
#   'oh',
#   'that',
#   'dreamy',
#   'son',
#   'of',
#   'a',
#   'bitch'],
#  ['3',
#   'bud',
#   'Lites',
#   'and',
#   '4',
#   'well',
#   'shots',
#   'at',
#   'the',
#   'bar',
#   'tn',
#   'plus',
#   'Im',
#   'giving',
#   'away',
#   'a',
#   'trip',
#   'to',
#   'Las',
#   'Vegas',
#   'So',
#   'if',
#   'youre',
#   'not',
#   'a',
#   'cunt',
#   'come',
#   'visit',
#   'me',
#   'at',
#   'Bourbon',
#   'St'],
#  ['60',
#   'torch',
#   'down',
#   'the',
#   'drain',
#   'cause',
#   'either',
#   'I',
#   'was',
#   'to',
#   'high',
#   'and',
#   'lost',
#   'it',
#   'or',
#   'one',
#   'of',
#   'my',
#   'niggas',
#   'finessed',
#   'that',
#   'hoe',
#   'fuckkkkk',
#   'ittt'],
#  ['',
#   'Killer',
#   'line',
#   'Josh',
#   'Smith',
#   'dropped',
#   'a',
#   'killer',
#   'trash',
#   'talk',
#   'line',
#   'on',
#   'Kenneth',
#   'tcoC8d3sJoUpj'],
#  ['', 'A', 'piece', 'of', 'pussy', 'tcoBcWiT2nuz5'],
#  ['',
#   'I',
#   'love',
#   'salad',
#   'Anyway',
#   'fuck',
#   'you',
#   'hoes',
#   'eat',
#   'a',
#   'salad'],
#  ['', 'plus', 'Sheryl', 'crow', 'tco49KYwZnotU'],
#  ['',
#   'Every',
#   'bitch',
#   'n',
#   'my',
#   'passenger',
#   'seat',
#   'I',
#   'dun',
#   'fucked',
#   'at',
#   'least',
#   'one',
#   'time'],
#  ['',
#   'its',
#   'true',
#   'that',
#   'the',
#   'early',
#   'bird',
#   'gets',
#   'the',
#   'worm',
#   'first'],
#  ['',
#   'dirty',
#   'whore',
#   'I',
#   'love',
#   'you',
#   'but',
#   'you',
#   'a',
#   'hoe',
#   'but',
#   'I',
#   'love',
#   'you',
#   'Jesus',
#   'is',
#   'watching'],
#  ['',
#   'This',
#   'hoe',
#   'got',
#   'a',
#   'school',
#   'shirt',
#   'on',
#   'sucking',
#   'dick',
#   ''],
#  ['',
#   'A',
#   'lotta',
#   'fck',
#   'niggas',
#   'on',
#   'this',
#   'here',
#   'Twitter',
#   'Really',
#   'be',
#   'talking',
#   'like',
#   'bitches'],
#  ['',
#   'These',
#   'bitches',
#   'started',
#   'shooting',
#   'at',
#   'my',
#   'party',
#   'Fuck',
#   'New',
#   'Orleans'],
#  ['', 'bitches', 'giving', 'back', 'rubs', ''],
#  ['never',
#   'been',
#   'a',
#   'coon',
#   'grew',
#   'up',
#   'with',
#   'bokoo',
#   'coons',
#   'tho',
#   'but',
#   'never',
#   'was',
#   '1',
#   'I',
#   'did',
#   'some',
#   'coon',
#   'shit',
#   'tho'],
#  ['',
#   'Nigga',
#   'was',
#   'smashing',
#   'his',
#   'hoe',
#   'had',
#   'his',
#   'hoe',
#   'paying',
#   'for',
#   'a',
#   'condo',
#   'and',
#   'he',
#   'still',
#   'with',
#   'her',
#   'Yep',
#   'Fucboy'],
#  ['', 'watching', 'niggers', 'fight', 'on', 'YouTubeVineIG'],
#  ['',
#   'Dont',
#   'like',
#   'me',
#   'Have',
#   'a',
#   'with',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'bitches',
#   'waiting',
#   'for',
#   'me',
#   'to',
#   'give',
#   'a',
#   'fuck',
#   ''],
#  ['',
#   'Id',
#   'rather',
#   'be',
#   'called',
#   'nigger',
#   'than',
#   'a',
#   'uncle',
#   'tom',
#   'or',
#   'a',
#   'mark'],
#  ['',
#   'Bet',
#   'yall',
#   'bitches',
#   'was',
#   'deaf',
#   'to',
#   'MC',
#   'Lytes',
#   'words',
#   'about',
#   'being',
#   'treated',
#   'like',
#   'a',
#   'queen',
#   'huh'],
#  ['', 'hiho', 'tcoFiC4FnRutZ'],
#  ['',
#   'Onea',
#   'yall',
#   'btches',
#   'gon',
#   'end',
#   'up',
#   'dead',
#   'over',
#   'a',
#   'screen',
#   'shot',
#   'thinkn',
#   'that',
#   'sht',
#   'funnyaint',
#   'too',
#   'many',
#   'niccas',
#   'gon',
#   'laugh',
#   'at',
#   'that',
#   'b'],
#  ['',
#   'congrats',
#   'youve',
#   'turned',
#   'a',
#   'hoe',
#   'into',
#   'a',
#   'housewife',
#   'dont',
#   'get',
#   'shitty',
#   'when',
#   'your',
#   'guys',
#   'start',
#   'singing',
#   'they',
#   'hit',
#   'it',
#   'first',
#   ''],
#  ['', 'got', 'ur', 'bitch', 'tip', 'toeing', 'on', 'my', 'marble', 'floors'],
#  ['',
#   'omg',
#   'just',
#   'thinccin',
#   'of',
#   'you',
#   'makes',
#   'me',
#   'laugh',
#   'we',
#   'use',
#   'to',
#   'STAY',
#   'talking',
#   'shit',
#   'in',
#   '3rd',
#   'period',
#   'you',
#   'cute',
#   'amp',
#   'you',
#   'my',
#   'bitch',
#   ''],
#  ['', 'you', 'needa', 'stop', 'sucking', 'dick', 'hoe', ''],
#  ['',
#   'OMG',
#   'LIL',
#   'B',
#   'FOLLOWED',
#   'ME',
#   'YASSSS',
#   'bitch',
#   'he',
#   'follow',
#   'everybody',
#   'shut',
#   'yo',
#   'ass',
#   'up'],
#  ['', 'hop', 'off', 'hoe', 'Come', 'on', ''],
#  ['',
#   'lmao',
#   'my',
#   'nigga',
#   'Lets',
#   'go',
#   'half',
#   'on',
#   'a',
#   'weed',
#   'brownie',
#   'we',
#   'will',
#   'be',
#   'laughing',
#   'hard',
#   'as',
#   'hell',
#   'in',
#   'senior',
#   'seminar'],
#  ['',
#   'amp',
#   'if',
#   'you',
#   'aint',
#   'a',
#   'ho',
#   'get',
#   'up',
#   'out',
#   'my',
#   'trap',
#   'hooouseee'],
#  ['',
#   'ugh',
#   'bitch',
#   'I',
#   'love',
#   'you',
#   'amp',
#   'that',
#   'A',
#   'S',
#   'S',
#   'your',
#   'just',
#   'simply',
#   'FLAWLESS',
#   'I',
#   'remember',
#   'when',
#   'you',
#   'cute',
#   'a',
#   'peice',
#   'of',
#   'your',
#   'hair',
#   'hella',
#   'short',
#   ''],
#  ['', 'pussy', 'ride', 'dick', 'like', 'she', 'a', 'Jamaican', 'gt', 'amp'],
#  ['', 'on', 'the', 'pussy', 'tcomWXQnjm4So'],
#  ['', 'Loyal', 'pussy', ''],
#  ['', 'my', 'bitch', ''],
#  ['',
#   'is',
#   'the',
#   'most',
#   'important',
#   'thing',
#   'All',
#   'this',
#   'temporary',
#   'bullshit',
#   'and',
#   'lies',
#   'is',
#   'fa',
#   'the',
#   'birds',
#   'Kill',
#   'that',
#   ''],
#  ['', 'Racist', 'all', 'month', 'Fuck', 'u', 'honkey'],
#  ['',
#   'Gucci',
#   'b',
#   'having',
#   'me',
#   'on',
#   'my',
#   'rude',
#   'shit',
#   'Lol',
#   'thats',
#   'not',
#   'nice',
#   'that',
#   'bitch',
#   'aint',
#   'worth',
#   'a',
#   'quarter',
#   ''],
#  ['',
#   'Mimi',
#   'too',
#   'old',
#   'to',
#   'be',
#   'covering',
#   'her',
#   'titties',
#   'during',
#   'sex',
#   'bitch',
#   'you',
#   'childish'],
#  ['',
#   'LMFAO',
#   'If',
#   'you',
#   'watching',
#   'porn',
#   'amp',
#   'beating',
#   'off',
#   'amp',
#   'yo',
#   'homie',
#   'text',
#   'u',
#   'amp',
#   'it',
#   'show',
#   'his',
#   'name',
#   'in',
#   'the',
#   'banner',
#   'youre',
#   'a',
#   'faggot'],
#  ['', 'bruh', 'these', 'hoes', 'gotta', 'be', 'stupid'],
#  ['',
#   'SOMEBODY',
#   'GONNA',
#   'DIE',
#   'theres',
#   'a',
#   'bitch',
#   'on',
#   'NJT',
#   'setting',
#   'up',
#   'a',
#   'lean',
#   'as',
#   'we',
#   'tweet'],
#  ['',
#   'Yall',
#   'have',
#   'boring',
#   'sex',
#   'Nope',
#   'I',
#   'lick',
#   'the',
#   'side',
#   'of',
#   'my',
#   'bitch',
#   'face',
#   'when',
#   'Im',
#   'hittin',
#   'it',
#   'from',
#   'the',
#   'back'],
#  ['',
#   'Of',
#   'course',
#   'cooders',
#   'nudes',
#   'are',
#   'trash',
#   'She',
#   'lives',
#   'in',
#   'the',
#   'DMV',
#   'what',
#   'did',
#   'you',
#   'expect',
#   ''],
#  ['',
#   'My',
#   'stomach',
#   'in',
#   'pain',
#   'like',
#   'a',
#   'mufucka',
#   'This',
#   'the',
#   'nigga',
#   'thats',
#   'rating',
#   'bitches',
#   '310',
#   'tcoyFlFuBJ2Po'],
#  ['', 'bitches', 'get', 'stuff', 'done', 'tcoGvFpk65ah5'],
#  ['', 'fucc', 'nicca', 'yu', 'pose', 'to', 'be', 'pullin', 'up'],
#  ['',
#   'maaaaannnn',
#   'i',
#   'hope',
#   'so',
#   'did',
#   'we',
#   'get',
#   'rid',
#   'of',
#   'John',
#   'Legend',
#   'looking',
#   'Charlie',
#   'Batch'],
#  ['', 'mike', 'calls', 'me', 'tbird', ''],
#  ['',
#   'niggas',
#   'sending',
#   'screenshots',
#   'of',
#   'me',
#   'to',
#   'they',
#   'bitches',
#   'like',
#   'stop',
#   'texting',
#   'cuh',
#   ''],
#  ['',
#   'this',
#   'white',
#   'bitch',
#   'think',
#   'she',
#   'miley',
#   'cyrus',
#   'tcolFfy5HvcNa'],
#  ['',
#   'i',
#   'seen',
#   'a',
#   'thot',
#   'ass',
#   'bitch',
#   'in',
#   'some',
#   'high',
#   'top',
#   'whites'],
#  ['', 'Nicca', 'gotta', 'team', 'full', 'of', 'worsum', 'hoes'],
#  ['',
#   'this',
#   'hoe',
#   'just',
#   'DMd',
#   'me',
#   'sayin',
#   'never',
#   'give',
#   'up',
#   'in',
#   'your',
#   'dreamsfuckin',
#   'fortune',
#   'cookie',
#   'ass',
#   'hoe',
#   'fuck',
#   'out',
#   'my',
#   'DMs'],
#  ['', 'When', 'a', 'dyke', 'get', 'pregnant', 'by', 'mistake', 'gtgtgtgtgt'],
#  ['',
#   'bitch',
#   'i',
#   'know',
#   'you',
#   'got',
#   'games',
#   'on',
#   'your',
#   'phone',
#   'tcoI2HyINFIdW'],
#  ['', 'bitch', 'my', 'lrt'],
#  ['', 'burnt', 'pussy', 'lips'],
#  ['',
#   'i',
#   'just',
#   'said',
#   'that',
#   'My',
#   'TL',
#   'gotta',
#   'chill',
#   'with',
#   'this',
#   'pretty',
#   'face',
#   'challenge',
#   'foolishness',
#   'yall',
#   'hoes',
#   'agg'],
#  ['',
#   'nah',
#   'if',
#   'you',
#   'round',
#   'me',
#   'you',
#   'do',
#   'Molly',
#   'Only',
#   'bitches',
#   'with',
#   'no',
#   'nigga',
#   'do',
#   'Mollies'],
#  ['',
#   'played',
#   'that',
#   'nigga',
#   'smh',
#   'bitches',
#   'are',
#   'so',
#   'shady',
#   'oh',
#   'my',
#   'god',
#   'tco1VhC9LqsKg'],
#  ['', 'No', 'bitch', 'go', 'away', 'tu', 'puta', 'madre', ''],
#  ['', 'bitch', 'was', 'mad', 'af', 'tco9C4i4W7Q7D'],
#  ['',
#   'I',
#   'hate',
#   'you',
#   'Cyrus',
#   'ho',
#   'is',
#   'a',
#   'rookie',
#   'slut',
#   'getting',
#   'the',
#   'cash',
#   'after',
#   'the',
#   'date',
#   'nope',
#   'nope',
#   'nope'],
#  ['',
#   'when',
#   'youre',
#   'trying',
#   'to',
#   'relax',
#   'but',
#   'your',
#   'pussy',
#   'is',
#   'shooting',
#   'out',
#   'light',
#   'beams',
#   'tco5eHbmr8TKo'],
#  ['', 'Murda', 'out', 'here', 'sucking', 'bitches', ''],
#  ['',
#   'bitch',
#   'if',
#   'youre',
#   'the',
#   'hobbit',
#   'you',
#   'need',
#   'to',
#   'let',
#   'me',
#   'know',
#   'right',
#   'now',
#   ''],
#  ['',
#   'these',
#   'folks',
#   'so',
#   'bad',
#   'Im',
#   'just',
#   'here',
#   'to',
#   'talk',
#   'trash'],
#  ['', 'brittany', 'bitch', 'u', 'my', 'dog', 'man', ''],
#  ['', 'smh', 'bitch', 'sellin', 'her', 'ass'],
#  ...]
